# %%
print("Hello, There!!")
# Out:
# Hello, There!!

# %%
import numpy as np
import pandas as pd

# %%
import django
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import django
#
# ModuleNotFoundError: No module named 'django'

# %% [markdown]
# # Varibles
# Variables en python

# %%
edad = 30
nombre = "Jose"
enfermo = True
pi = 3.1416
print(type(edad))
print(type(pi))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# # Funciones con Python

# %%
def suma(a, b):
    return a + b

# %%
print("La suma de 10 + 10 es:", suma(10,10))
# Out:
# La suma de 10 + 10 es: 20

# %% [markdown]
# # Estructuras de datos con Python
# Listas, Tuplas, Diccionarios

# %%
my_list = ["Juan", pi, enfermo, 1234]
print(my_list[1])
print(my_list[0])
# Out:
# 3.1416
# Juan

# %%
for i in my_list:
    print(i)
# Out:
# Juan
# 3.1416
# True
# 1234

# %%
for i in my_list:
    if i == 3.1416:
        print("Loteriaaaaa")
    else:
        print(i)
# Out:
# Juan
# Loteriaaaaa
# True
# 1234

# %%
my_list[0]= "Polo"

# %%
print(my_list[0])
# Out:
# Polo

# %%
for i in my_list:
    print(i)
# Out:
# Polo
# 3.1416
# True
# 1234

# %%
my_list.append("Pizza")

# %%
for i in my_list:
    print(i)
# Out:
# Polo
# 3.1416
# True
# 1234
# Pizza

# %%
my_list.pop()
# Out:
# 'Pizza'

# %%
for i in my_list:
    print(i)
# Out:
# Polo
# 3.1416
# True
# 1234

# %%
my_tup = (12, "Hola")

# %%
my_tup[0]
# Out:
# 12

# %%
for i in my_tup:
    print(i)
# Out:
# 12
# Hola

# %%
diccionario = {"ventas": [{"Junio": 125000, "Julio": 200000}]}

# %%
diccionario["ventas"]
# Out:
# [{'Junio': 125000, 'Julio': 200000}]

# %%
for k in diccionario:
    print(diccionario[k][0])
# Out:
# {'Junio': 125000, 'Julio': 200000}
